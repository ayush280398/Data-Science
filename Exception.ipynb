# %%
#Q1
'''
An exception is an event, which occurs during the execution of a program that disrupts the normal flow of 
the program's instructions.

Syntax errors are mistakes in the source code, such as spelling and punctuation errors, incorrect labels,
and so on which cause an error message to be generated by the compiler And Whereas an Exception occurs at runtime 
'''
# Out:
# "\nAn exception is an event, which occurs during the execution of a program that disrupts the normal flow of \nthe program's instructions.\n\nSyntax errors are mistakes in the source code, such as spelling and punctuation errors, incorrect labels,\nand so on which cause an error message to be generated by the compiler And Whereas an Exception occurs at runtime \n"

# %%
#Q2
'''
When an exception is not handled, it results in an uncaught exception. In programming, exceptions are raised when an error or unexpected situation occurs during the execution of a program. If the exception is not caught and handled properly, the program will terminate abruptly, and the error message or stack trace will be displayed, 
which can be disruptive to the user and may lead to data loss or other unexpected behavior.

'''
#Example
def divide_numbers(a, b):
    result = a / b
    return result

try:
    num1 = int(input("Enter the first number: "))
    num2 = int(input("Enter the second number: "))
    result = divide_numbers(num1, num2)
    print(f"The result of division is: {result}")
except ValueError:
    print("Invalid input! Please enter valid integers.")

# %%
#Q3
#a
try:
  print("Hello")
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")

#b
try:
  print(x)
except:
  print("Something went wrong")
finally:
  print("The 'try except' is finished")

#c

x = -1

if x < 0:
  raise Exception("Sorry, no numbers below zero")

# %%
#Q4
''' 
Custom exceptions in Python are user-defined exceptions that allow developers to create their own specific exception classes to represent unique error scenarios in their programs. 
Python provides the ability to create custom exception classes by inheriting from the built-in 
Exception class or any of its subclasses.

We need custom exceptions when we encounter specific error conditions in our code that are not adequately represented by the built-in exception classes.
'''
#Example

class CustomError(Exception):
    pass

raise CustomError("Example of Custom Exceptions in Python")

# %%
#Q5

class InvalidInputError(Exception):
    def __init__(self, message):
        self.message = message

    def __str__(self):
        return f"Invalid Input: {self.message}"


def divide_numbers(a, b):
    if b == 0:
        raise InvalidInputError("Cannot divide by zero.")
    return a / b



if __name__ == "__main__":
    try:
        num1 = int(input("Enter the first number: "))
        num2 = int(input("Enter the second number: "))
        result = divide_numbers(num1, num2)
        print(f"The result of division is: {result}")
    except ValueError:
        print("Invalid input! Please enter valid integers.")
    except InvalidInputError as e:
        print(e)
